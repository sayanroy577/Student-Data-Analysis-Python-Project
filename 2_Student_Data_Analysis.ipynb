# %% [markdown]
# <a href="https://colab.research.google.com/github/sayanroy577/Student-Data-Analysis-Python-Project/blob/main/2_Student_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Uploading Dataframe

# %%
df=pd.read_csv('Student.csv')
df
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2  Krishna     99  Female
# 3   Vedant     87   Male
# 4   Parshv     91    Male
# 5   Shreya     83  Female
# 6  Archana     99  Female

# %% [markdown]
# # 1.Display top 3 rows of dataframe

# %%
df.head(3)
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2  Krishna     99  Female

# %% [markdown]
# # 2.Display last 3 rows of dataframe

# %%
df.tail(3)
# Out:
#       Name  Marks  Gender
# 4   Parshv     91    Male
# 5   Shreya     83  Female
# 6  Archana     99  Female

# %% [markdown]
# # 3.Find number of Columns & Rows of Dataframe

# %%
df.shape
# Out:
# (7, 3)

# %%
print("Number of Columns :",df.shape[1])
print("Number of Rows :",df.shape[0])
# Out:
# Number of Columns : 3
# Number of Rows : 7

# %% [markdown]
# # 4.Get information about dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Marks   7 non-null      int64
#  2   Gender  7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 296.0+ bytes

# %% [markdown]
# # 5.Check null values of dataframe

# %%
df.isnull().sum()
# Out:
# Name      0
# Marks     0
# Gender    0
# dtype: int64

# %% [markdown]
# # 6.Find overall statistics about the dataframe.

# %%
df.describe()
# Out:
#            Marks
# count   7.000000
# mean   92.285714
# std     6.447591
# min    83.000000
# 25%    88.000000
# 50%    91.000000
# 75%    98.500000
# max    99.000000

# %% [markdown]
# # 7.Find Unique values from gender column

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# # 8.Find the number of unique values from the gender column

# %%
df['Gender'].nunique()
# Out:
# 2

# %% [markdown]
# # 9.Display count of unique values from gender column

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    4
# Male      3
# Name: count, dtype: int64

# %% [markdown]
# # 10.Find total number of students having marks between 90 to 100(using & without using Between Method)

# %%
sum(df['Marks'].between(90,100))
# Out:
# 4

# %%
len(df[(df['Marks']>90) & (df['Marks']<100)])
# Out:
# 4

# %% [markdown]
# # 11.Find Average Marks

# %%
df['Marks'].mean()
# Out:
# 92.28571428571429

# %% [markdown]
# #  12.Change categorical to numerical value of gender column with the help of map function & create a new column.

# %%
df['Male&Female']=df['Gender'].map({'Male':1,'Female':0})

# %%
df
# Out:
#       Name  Marks  Gender  Male&Female
# 0  Priyang     98    Male            1
# 1   Aadhya     89  Female            0
# 2  Krishna     99  Female            0
# 3   Vedant     87    Male            1
# 4   Parshv     91    Male            1
# 5   Shreya     83  Female            0
# 6  Archana     99  Female            0

# %% [markdown]
# # 13.Drop the new columns

# %%
df.drop(columns=["Male&Female"],inplace=True)

# %%
df
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2  Krishna     99  Female
# 3   Vedant     87    Male
# 4   Parshv     91    Male
# 5   Shreya     83  Female
# 6  Archana     99  Female

# %% [markdown]
# # 14.Print name of columns

# %%
df.columns
# Out:
# Index(['Name', 'Marks', 'Gender'], dtype='object')

# %% [markdown]
# # 15.Sort the dataframe as per the marks column in both ascending & descending order

# %%
df.sort_values(by=['Marks'],ascending=False)
# Out:
#       Name  Marks  Gender
# 2  Krishna     99  Female
# 6  Archana     99  Female
# 0  Priyang     98    Male
# 4   Parshv     91    Male
# 1   Aadhya     89  Female
# 3   Vedant     87    Male
# 5   Shreya     83  Female

# %%
df.sort_values(by=['Marks'])
# Out:
#       Name  Marks  Gender
# 5   Shreya     83  Female
# 3   Vedant     87    Male
# 1   Aadhya     89  Female
# 4   Parshv     91    Male
# 0  Priyang     98    Male
# 2  Krishna     99  Female
# 6  Archana     99  Female

# %% [markdown]
# # 16.Display name & marks of the female students

# %%
df[df['Gender']=='Female'][['Name','Marks']]
# Out:
#       Name  Marks
# 1   Aadhya     89
# 2  Krishna     99
# 5   Shreya     83
# 6  Archana     99
